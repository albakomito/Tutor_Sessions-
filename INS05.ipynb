# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
# Read CSV, parse dates, and set index
csvpath = Path('AirPassengers.csv')
df = pd.read_csv(csvpath, parse_dates=True, index_col='Month', infer_datetime_format=True)
df.head()
# Out:
#             NumberPassengers
# Month
# 1949-01-01               112
# 1949-02-01               118
# 1949-03-01               132
# 1949-04-01               129
# 1949-05-01               121

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
plot_acf(df, lags=20)

# %%
plot_pacf(df, lags=20)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(df['NumberPassengers'], order=(2,1,2))
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
# Check model for fit and summary 
results = model.fit()
results.summary()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  144
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -671.673
# Date:                Thu, 28 Apr 2022   AIC                           1353.347
# Time:                        10:29:32   BIC                           1368.161
# Sample:                    01-01-1949   HQIC                          1359.366
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6850      0.020     83.058      0.000       1.645       1.725
# ar.L2         -0.9548      0.017    -55.419      0.000      -0.989      -0.921
# ma.L1         -1.8432      0.125    -14.772      0.000      -2.088      -1.599
# ma.L2          0.9953      0.135      7.362      0.000       0.730       1.260
# sigma2       665.9537    114.224      5.830      0.000     442.079     889.829
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                 1.84
# Prob(Q):                              0.59   Prob(JB):                         0.40
# Heteroskedasticity (H):               7.38   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# From Armando (04/25 21:15)
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)



train_size = 0.75
train_df = df[0:int(len(df)*train_size)]


def get_predictions(train_df, p, d, q, num_steps=20): 
    model = ARIMA(train_df , order=(p,d,q))
    results = model.fit()
    print(results.summary())
    test_predictions = pd.DataFrame(results.forecast(steps=num_steps)[0])
    test_predictions.columns = ['NumberPassengers']

    start_index = int(len(df)*train_size)
    end_index = start_index + num_steps

    test_predictions.index = df[start_index:end_index].index
    return test_predictions 



combinations_to_test = [(2,1,2), (1,1,1), (2,1,1), (1,1,2), (2,1,4)]

summary = []
for combination in combinations_to_test: 
    try: 
        p = combination[0]
        d = combination[1]
        q = combination[2]
        print("Adding output from model p:{}, d:{}, q:{}".format(p,d,q))
        output = get_predictions(train_df, p, d, q, num_steps=20)
        model_name = 'model p:{}, d:{}, q:{}'.format(p,d,q)
        summary.append([output, model_name])
        
    except: 
        print("p:{}, d:{}, q:{} are not viable".format(p,d,q))
        
        
import matplotlib.pyplot as plt
num_steps= 20
true_df = df.iloc[0:len(train_df)+num_steps]


plt.figure(figsize=(20,10))
plt.plot(true_df.index, true_df['NumberPassengers'], label='Original Signal')

for model in summary: 
    test_predictions = model[0]
    model_name = model[1]
    plt.plot(test_predictions.index, test_predictions['NumberPassengers'],label=model_name)
    
plt.title("Comparing True values with Predicted Values", fontsize=20)
plt.ylabel("Number of Passengers")
plt.xlabel("Date")
plt.legend()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# Adding output from model p:2, d:1, q:2
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  108
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -486.916
# Date:                Thu, 28 Apr 2022   AIC                            983.832
# Time:                        10:29:32   BIC                            997.196
# Sample:                    01-01-1949   HQIC                           989.250
#                          - 12-01-1957
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3899      0.144      2.715      0.007       0.108       0.671
# ar.L2          0.1415      0.192      0.737      0.461      -0.235       0.518
# ma.L1         -0.0980      0.113     -0.869      0.385      -0.319       0.123
# ma.L2         -0.6691      0.139     -4.819      0.000      -0.941      -0.397
# sigma2       521.2447     96.772      5.386      0.000     331.576     710.914
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 3.24
# Prob(Q):                              0.93   Prob(JB):                         0.20
# Heteroskedasticity (H):               4.57   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# p:2, d:1, q:2 are not viable
# Adding output from model p:1, d:1, q:1
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  108
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -490.640
# Date:                Thu, 28 Apr 2022   AIC                            987.280
# Time:                        10:29:32   BIC                            995.299
# Sample:                    01-01-1949   HQIC                           990.531
#                          - 12-01-1957
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4856      0.136     -3.567      0.000      -0.752      -0.219
# ma.L1          0.8760      0.078     11.289      0.000       0.724       1.028
# sigma2       559.5788     94.858      5.899      0.000     373.661     745.496
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 1.75
# Prob(Q):                              0.80   Prob(JB):                         0.42
# Heteroskedasticity (H):               4.60   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# p:1, d:1, q:1 are not viable
# Adding output from model p:2, d:1, q:1
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  108
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -486.590
# Date:                Thu, 28 Apr 2022   AIC                            981.181
# Time:                        10:29:32   BIC                            991.872
# Sample:                    01-01-1949   HQIC                           985.515
#                          - 12-01-1957
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0506      0.107      9.849      0.000       0.842       1.260
# ar.L2         -0.4606      0.112     -4.121      0.000      -0.680      -0.242
# ma.L1         -0.8145      0.104     -7.800      0.000      -1.019      -0.610
# sigma2       518.4064     70.145      7.390      0.000     380.924     655.888
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.44   Jarque-Bera (JB):                 7.89
# Prob(Q):                              0.51   Prob(JB):                         0.02
# Heteroskedasticity (H):               5.03   Skew:                             0.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# p:2, d:1, q:1 are not viable
# Adding output from model p:1, d:1, q:2
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  108
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                -487.070
# Date:                Thu, 28 Apr 2022   AIC                            982.140
# Time:                        10:29:33   BIC                            992.831
# Sample:                    01-01-1949   HQIC                           986.474
#                          - 12-01-1957
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5258      0.123      4.269      0.000       0.284       0.767
# ma.L1         -0.2263      0.123     -1.835      0.066      -0.468       0.015
# ma.L2         -0.5436      0.086     -6.297      0.000      -0.713      -0.374
# sigma2       523.1555     95.930      5.454      0.000     335.137     711.174
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 3.76
# Prob(Q):                              0.63   Prob(JB):                         0.15
# Heteroskedasticity (H):               4.70   Skew:                             0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# p:1, d:1, q:2 are not viable
# Adding output from model p:2, d:1, q:4
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Owner\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       NumberPassengers   No. Observations:                  108
# Model:                 ARIMA(2, 1, 4)   Log Likelihood                -474.593
# Date:                Thu, 28 Apr 2022   AIC                            963.187
# Time:                        10:29:33   BIC                            981.896
# Sample:                    01-01-1949   HQIC                           970.771
#                          - 12-01-1957
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9139      0.074     12.272      0.000       0.768       1.060
# ar.L2         -0.8009      0.066    -12.168      0.000      -0.930      -0.672
# ma.L1         -0.6572      0.108     -6.060      0.000      -0.870      -0.445
# ma.L2          0.3850      0.198      1.941      0.052      -0.004       0.774
# ma.L3          0.3765      0.111      3.396      0.001       0.159       0.594
# ma.L4         -0.6149      0.141     -4.353      0.000      -0.892      -0.338
# sigma2       395.0515     96.668      4.087      0.000     205.585     584.518
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 3.63
# Prob(Q):                              0.53   Prob(JB):                         0.16
# Heteroskedasticity (H):               4.19   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# p:2, d:1, q:4 are not viable
